# %% [markdown]
# # Output Examples
# Simple checks for files generated by `analysis.py`.

# %%
from pathlib import Path
out = Path('outputs')
sorted([p.name for p in out.glob('*')])
# Out:
# []

# %%
import pandas as pd
summary = pd.read_csv('../outputs/summary_by_region.csv')
summary.sort_values('total_revenue', ascending=False).head(10)
# Out:
#       region  category  total_units  total_revenue  orders  \
# 0  Northeast  hardware            7         1422.0       4
# 1    Midwest  hardware            9         1071.0       4
# 2       West  software           29          766.0       4
# 3      South  hardware            7          751.0       4
# 4  Northeast  software           23          704.0       4
# 5       West  hardware           12          703.0       4
# 6    Midwest  software           19          623.0       4
# 7      South  software           17          538.0       4
# 8  Northeast    office           35          323.5       4
# 9       West    office           33          316.0       4
#
#    avg_revenue_per_order
# 0                 355.50
# 1                 267.75
# 2                 191.50
# 3                 187.75
# 4                 176.00
# 5                 175.75
# 6                 155.75
# 7                 134.50
# 8                  80.88
# 9                  79.00
