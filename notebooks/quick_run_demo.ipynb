# %% [markdown]
# # Quick Run Demo
# This notebook shows one way to run the project script and inspect outputs.

# %%
from pathlib import Path
import subprocess

repo = Path('..').resolve()
subprocess.run(['python', str(repo / 'scripts/analysis.py')], check=False)
# Out:
# Analysis complete.
# Rows in summary: 12
# Summary written to: /Users/julianaantovski/Desktop/CMSE492/hw01-antovsk4/outputs/summary_by_region.csv
# Plot written to: /Users/julianaantovski/Desktop/CMSE492/hw01-antovsk4/outputs/revenue_by_region.png
# CompletedProcess(args=['python', '/Users/julianaantovski/Desktop/CMSE492/hw01-antovsk4/scripts/analysis.py'], returncode=0)

# %%
import pandas as pd
pd.read_csv('../outputs/summary_by_region.csv').head()
# Out:
#       region  category  total_units  total_revenue  orders  \
# 0  Northeast  hardware            7         1422.0       4
# 1    Midwest  hardware            9         1071.0       4
# 2       West  software           29          766.0       4
# 3      South  hardware            7          751.0       4
# 4  Northeast  software           23          704.0       4
#
#    avg_revenue_per_order
# 0                 355.50
# 1                 267.75
# 2                 191.50
# 3                 187.75
# 4                 176.00
